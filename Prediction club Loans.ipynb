# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'new_lending_club_loans.csv',low_memory=False)

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599     5000.0       5000.0       4975.00000
# 1      1077430    1314167     2500.0       2500.0       2500.00000
# 2      1077175    1313524     2400.0       2400.0       2400.00000
# 3      1076863    1277178    10000.0      10000.0      10000.00000
# 4      1075358    1311748     3000.0       3000.0       3000.00000
# 5      1075269    1311441     5000.0       5000.0       5000.00000
# 6      1069639    1304742     7000.0       7000.0       7000.00000
# 7      1072053    1288686     3000.0       3000.0       3000.00000
# 8      1071795    1306957     5600.0       5600.0       5600.00000
# 9      1071570    1306721     5375.0       5375.0       5350.00000
# 10     1070078    1305201     6500.0       6500.0       6500.00000
# 11     1069908    1305008    12000.0      12000.0      12000.00000
# 12     1064687    1298717     9000.0       9000.0       9000.00000
# ...

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid         35574
# Charged Off         6414
# Current              513
# Late                  17
# In Grace Period       16
# Default                1
# Name: loan_status, dtype: int64

# %%
df['pymnt_plan'].value_counts()
# Out:
# n    42534
# y        1
# Name: pymnt_plan, dtype: int64

# %%
df['addr_state'].value_counts()
# Out:
# CA    7429
# NY    4065
# FL    3104
# TX    2915
# NJ    1988
# IL    1672
# PA    1651
# GA    1503
# VA    1487
# MA    1438
# OH    1329
# MD    1125
# AZ     933
# WA     888
# CO     857
# NC     830
# CT     816
# MI     796
# MO     765
# MN     652
# NV     527
# WI     516
# SC     489
# AL     484
# OR     468
# LA     461
# KY     359
# OK     317
# KS     298
# UT     278
# AR     261
# DC     224
# RI     208
# NM     205
# NH     188
# WV     187
# HI     181
# DE     136
# MT      96
# WY      87
# AK      86
# SD      67
# VT      57
# TN      32
# MS      26
# IN      19
# IA      12
# NE      11
# ID       9
# ME       3
# Name: addr_state, dtype: int64

# %%
df['title'].value_counts()
# Out:
# Debt Consolidation                          2259
# Debt Consolidation Loan                     1760
# Personal Loan                                708
# Consolidation                                547
# debt consolidation                           532
# Home Improvement                             373
# Credit Card Consolidation                    370
# Debt consolidation                           347
# Small Business Loan                          333
# Personal                                     330
# Credit Card Loan                             323
# personal loan                                266
# Consolidation Loan                           264
# Home Improvement Loan                        255
# personal                                     247
# Loan                                         218
# Wedding Loan                                 217
# consolidation                                217
# Car Loan                                     206
# ...

# %%
droped_cols = ['pymnt_plan','addr_state','application_type','title']

# %%
df.drop(columns=droped_cols, axis=0, inplace=True)

# %%
df.sample()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 867  1058959    1290760    16500.0      16500.0          16500.0   36 months
#
#      installment grade sub_grade         emp_title  ... last_pymnt_amnt  \
# 867       586.39     D        D2  Edge Auto Rental  ...          604.94
#
#     last_credit_pull_d last_fico_range_high last_fico_range_low policy_code  \
# 867             Dec-14                689.0               685.0         1.0
#
#     pub_rec_bankruptcies emp_length_year  int_rate_%  revol_util_%  \
# 867                  0.0         2 years       16.77          70.2
#
#      total_payment
# 867       21109.72
#
# [1 rows x 48 columns]

# %%
drop_cols = ['id',
             'member_id',
             'funded_amnt',
             'funded_amnt_inv',
             'sub_grade',
             'int_rate_%',
             'emp_title',
             'issue_d',
             'zip_code',
             'out_prncp',
             'out_prncp_inv',
             'total_pymnt',
             'total_pymnt_inv',
             'total_rec_prncp',
             'total_rec_int',
             'total_rec_late_fee',
             'recoveries',
             'collection_recovery_fee',
             'last_pymnt_d',
             'last_pymnt_amnt',
            ]

# %%
df.drop(columns=drop_cols, axis=1, inplace=True)

# %%
droped_cols = ['initial_list_status',
             'last_credit_pull_d',
             'policy_code',
             'acc_now_delinq',
             'delinq_amnt',
             'pub_rec_bankruptcies',
            ]

# %%
df.sample()
# Out:
#        loan_amnt        term  installment grade home_ownership annual_inc  \
# 20061     6375.0   36 months       207.93     B           RENT    32000.0
#
#       verification_status loan_status             purpose    dti  ...  \
# 20061            Verified  Fully Paid  debt_consolidation  20.66  ...
#
#        total_acc  initial_list_status  last_credit_pull_d  \
# 20061       17.0                    f              Sep-16
#
#        last_fico_range_high  last_fico_range_low  policy_code  \
# 20061                 684.0                680.0          1.0
#
#        pub_rec_bankruptcies  emp_length_year  revol_util_% total_payment
# 20061                   0.0          7 years          47.5       6883.38
#
# [1 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42535 entries, 0 to 42534
# Data columns (total 28 columns):
# loan_amnt                 42535 non-null float64
# term                      42535 non-null object
# installment               42535 non-null float64
# grade                     42535 non-null object
# home_ownership            42535 non-null object
# annual_inc                42535 non-null object
# verification_status       42535 non-null object
# loan_status               42535 non-null object
# purpose                   42535 non-null object
# dti                       42535 non-null float64
# delinq_2yrs               42535 non-null float64
# fico_range_low            42535 non-null float64
# fico_range_high           42535 non-null float64
# inq_last_6mths            42535 non-null float64
# mths_since_last_delinq    42535 non-null float64
# open_acc                  42535 non-null float64
# pub_rec                   42535 non-null float64
# ...

# %%
df['loan_status']
# Out:
# 0         Fully Paid
# 1        Charged Off
# 2         Fully Paid
# 3         Fully Paid
# 4            Current
# 5         Fully Paid
# 6         Fully Paid
# 7         Fully Paid
# 8        Charged Off
# 9        Charged Off
# 10        Fully Paid
# 11        Fully Paid
# 12       Charged Off
# 13        Fully Paid
# 14       Charged Off
# 15        Fully Paid
# 16        Fully Paid
# 17        Fully Paid
# 18        Fully Paid
# 19        Fully Paid
# 20        Fully Paid
# 21       Charged Off
# 22        Fully Paid
# 23        Fully Paid
# 24       Charged Off
# 25        Fully Paid
# 26       Charged Off
# 27       Charged Off
# 28        Fully Paid
# 29        Fully Paid
#             ...
# 42505    Charged Off
# 42506     Fully Paid
# 42507     Fully Paid
# 42508     Fully Paid
# 42509     Fully Paid
# 42510     Fully Paid
# 42511     Fully Paid
# 42512     Fully Paid
# 42513     Fully Paid
# 42514     Fully Paid
# 42515     Fully Paid
# 42516     Fully Paid
# ...

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid         35574
# Charged Off         6414
# Current              513
# Late                  17
# In Grace Period       16
# Default                1
# Name: loan_status, dtype: int64

# %%
df = df[(df['loan_status']=='Fully Paid') | (df['loan_status']=='Charged Off')]

# %%
df.reset_index(drop=True, inplace=True)

# %%
X_df = df.drop(columns=['loan_status'], axis=1)
y_df = df['loan_status']

# %%
X_df.shape, y_df.shape
# Out:
# ((41988, 27), (41988,))

# %%
cat_cols = []
for data in X_df:
    if X_df[data].dtype == 'object':
        cat_cols.append(data)
print(cat_cols)
# Out:
# ['term', 'grade', 'home_ownership', 'annual_inc', 'verification_status', 'purpose', 'initial_list_status', 'last_credit_pull_d', 'emp_length_year']

# %%
X_df.drop(columns=cat_cols, inplace=True)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'installment', 'grade', 'home_ownership',
#        'annual_inc', 'verification_status', 'loan_status', 'purpose', 'dti',
#        'delinq_2yrs', 'fico_range_low', 'fico_range_high', 'inq_last_6mths',
#        'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'initial_list_status', 'last_credit_pull_d',
#        'last_fico_range_high', 'last_fico_range_low', 'policy_code',
#        'pub_rec_bankruptcies', 'emp_length_year', 'revol_util_%',
#        'total_payment'],
#       dtype='object')

# %%
x = df[['loan_amnt', 'term', 'installment', 'grade', 'home_ownership',
       'annual_inc', 'verification_status', 'loan_status', 'purpose', 'dti',
       'delinq_2yrs', 'fico_range_low', 'fico_range_high', 'inq_last_6mths',
       'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_bal',
       'total_acc', 'last_fico_range_high', 'last_fico_range_low',
       'emp_length_year', 'revol_util_%']]
y = df['loan_status']

# %%
x
# Out:
#        loan_amnt        term  installment grade home_ownership annual_inc  \
# 0         5000.0   36 months       162.87     B           RENT    24000.0
# 1         2500.0   60 months        59.83     C           RENT    30000.0
# 2         2400.0   36 months        84.33     C           RENT    12252.0
# 3        10000.0   36 months       339.31     C           RENT    49200.0
# 4         5000.0   36 months       156.46     A           RENT    36000.0
# 5         7000.0   60 months       170.08     C           RENT    47004.0
# 6         3000.0   36 months       109.43     E           RENT    48000.0
# 7         5600.0   60 months       152.39     F            OWN    40000.0
# 8         5375.0   60 months       121.45     B           RENT    15000.0
# 9         6500.0   60 months       153.45     C            OWN    72000.0
# 10       12000.0   36 months       402.54     B            OWN    75000.0
# 11        9000.0   36 months       305.38     C           RENT    30000.0
# ...

# %%
y
# Out:
# 0         Fully Paid
# 1        Charged Off
# 2         Fully Paid
# 3         Fully Paid
# 4         Fully Paid
# 5         Fully Paid
# 6         Fully Paid
# 7        Charged Off
# 8        Charged Off
# 9         Fully Paid
# 10        Fully Paid
# 11       Charged Off
# 12        Fully Paid
# 13       Charged Off
# 14        Fully Paid
# 15        Fully Paid
# 16        Fully Paid
# 17        Fully Paid
# 18        Fully Paid
# 19        Fully Paid
# 20       Charged Off
# 21        Fully Paid
# 22        Fully Paid
# 23       Charged Off
# 24        Fully Paid
# 25       Charged Off
# 26       Charged Off
# 27        Fully Paid
# 28        Fully Paid
# 29        Fully Paid
#             ...
# 41958    Charged Off
# 41959     Fully Paid
# 41960     Fully Paid
# 41961     Fully Paid
# 41962     Fully Paid
# 41963     Fully Paid
# 41964     Fully Paid
# 41965     Fully Paid
# 41966     Fully Paid
# 41967     Fully Paid
# 41968     Fully Paid
# 41969     Fully Paid
# ...

# %% [markdown]
# #  Training & Testing Data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X_df, y_df, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#        loan_amnt  installment    dti  delinq_2yrs  fico_range_low  \
# 36031    17000.0       576.69   7.03          0.0           685.0
# 8760      5000.0       166.05  18.83          1.0           680.0
# 9170     18000.0       437.63  23.27          0.0           715.0
# 23179    25000.0       408.88  24.87          0.0           695.0
# 33056     5000.0       172.38  16.57          0.0           740.0
# 33587    10000.0       316.11   4.15          0.0           780.0
# 14154     2000.0        67.38   1.74          0.0           680.0
# 30738    10000.0       322.11   6.64          0.0           735.0
# 38030     8000.0       251.64  10.81          0.0           665.0
# 23433    24250.0       298.36  23.56          0.0           745.0
# 844      10000.0       304.36  12.29          0.0           755.0
# 41952    15600.0       265.17  10.42          0.0           685.0
# 18486    14500.0       330.37  15.69          1.0           720.0
# ...

# %%
X_test
# Out:
#        loan_amnt  installment    dti  delinq_2yrs  fico_range_low  \
# 26389     8000.0       263.78   8.84          0.0           700.0
# 20509     6000.0       119.63   7.76          0.0           775.0
# 11321    25000.0       597.78  24.37          0.0           730.0
# 15482     6400.0       198.47  13.46          0.0           740.0
# 3539     17750.0       473.24  13.73          1.0           665.0
# 26686     6400.0       211.02  15.62          0.0           710.0
# 7755      5000.0       162.73   7.66          1.0           710.0
# 7134      6000.0       180.96   5.73          0.0           755.0
# 9640     15000.0       329.82  10.82          0.0           740.0
# 7422      5000.0       150.80  22.40          0.0           750.0
# 21068     3700.0       118.09  11.40          0.0           720.0
# 655      21000.0       657.10   3.69          0.0           740.0
# 36763    10000.0       320.95   2.47          0.0           740.0
# ...

# %%
y_train
# Out:
# 36031     Fully Paid
# 8760      Fully Paid
# 9170      Fully Paid
# 23179    Charged Off
# 33056     Fully Paid
# 33587     Fully Paid
# 14154     Fully Paid
# 30738     Fully Paid
# 38030     Fully Paid
# 23433     Fully Paid
# 844       Fully Paid
# 41952    Charged Off
# 18486     Fully Paid
# 31496     Fully Paid
# 33211     Fully Paid
# 15159     Fully Paid
# 19949     Fully Paid
# 32840     Fully Paid
# 34605     Fully Paid
# 39815     Fully Paid
# 36600     Fully Paid
# 7519      Fully Paid
# 41422     Fully Paid
# 8622      Fully Paid
# 1330      Fully Paid
# 32366     Fully Paid
# 9512      Fully Paid
# 22594     Fully Paid
# 17471     Fully Paid
# 7545      Fully Paid
#             ...
# 1899      Fully Paid
# 35773     Fully Paid
# 19118     Fully Paid
# 189      Charged Off
# 2747      Fully Paid
# 18431     Fully Paid
# 18942     Fully Paid
# 25658     Fully Paid
# 41434     Fully Paid
# 27480     Fully Paid
# 6396      Fully Paid
# 28693     Fully Paid
# ...

# %%
y_test
# Out:
# 26389     Fully Paid
# 20509     Fully Paid
# 11321     Fully Paid
# 15482     Fully Paid
# 3539     Charged Off
# 26686     Fully Paid
# 7755      Fully Paid
# 7134     Charged Off
# 9640      Fully Paid
# 7422      Fully Paid
# 21068     Fully Paid
# 655       Fully Paid
# 36763     Fully Paid
# 12364     Fully Paid
# 16051     Fully Paid
# 21445     Fully Paid
# 41851    Charged Off
# 11225     Fully Paid
# 16084     Fully Paid
# 41794     Fully Paid
# 21763    Charged Off
# 6756      Fully Paid
# 26070     Fully Paid
# 27395     Fully Paid
# 2276      Fully Paid
# 18967     Fully Paid
# 343       Fully Paid
# 29814     Fully Paid
# 32585     Fully Paid
# 22575     Fully Paid
#             ...
# 26565     Fully Paid
# 16728     Fully Paid
# 36069     Fully Paid
# 6462      Fully Paid
# 1255     Charged Off
# 23755     Fully Paid
# 23204     Fully Paid
# 17962     Fully Paid
# 36247     Fully Paid
# 25239     Fully Paid
# 33259     Fully Paid
# 2280      Fully Paid
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import metrics

# %% [markdown]
# # Logistic regression

# %%
log_model = LogisticRegression()

log_model.fit(X_train, y_train)

log_pred = log_model.predict(X_test)
# Out:
# C:\Users\DELL VOSTRO 1520\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(metrics.classification_report(y_test, log_pred))
# Out:
#               precision    recall  f1-score   support
#
#  Charged Off       0.93      0.76      0.83      1637
#   Fully Paid       0.96      0.99      0.97      8860
#
#     accuracy                           0.95     10497
#    macro avg       0.94      0.87      0.90     10497
# weighted avg       0.95      0.95      0.95     10497

# %%
print('Accuracy score is',log_model.score(X_test,y_test))
# Out:
# Accuracy score is 0.9523673430503954

# %%
svc_model = SVC(kernel='sigmoid')

svc_model.fit(X_train, y_train)

svc_pred = svc_model.predict(X_test)
# Out:
# C:\Users\DELL VOSTRO 1520\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print(metrics.classification_report(y_test, svc_pred))
# Out:
# C:\Users\DELL VOSTRO 1520\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#  Charged Off       0.00      0.00      0.00      1637
#   Fully Paid       0.84      1.00      0.92      8860
#
#     accuracy                           0.84     10497
#    macro avg       0.42      0.50      0.46     10497
# weighted avg       0.71      0.84      0.77     10497

# %%
print('Accuracy score is',svc_model.score(X_test,y_test))
# Out:
# Accuracy score is 0.8440506811469943
